# %%
# !pip -q install requests beautifulsoup4 lxml pandas dateparser tqdm
# Out:
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import re, time
from urllib.parse import urljoin
import requests
from bs4 import BeautifulSoup
import dateparser

BASE = "https://www.123telugu.com"
HEADERS = {"User-Agent":"Mozilla/5.0 (compatible; Latest123TeluguScraper/1.0)"}
TIMEOUT = 20

def soup(url):
    r = requests.get(url, headers=HEADERS, timeout=TIMEOUT)
    r.raise_for_status()
    return BeautifulSoup(r.text, "lxml")

def clean(s): 
    return re.sub(r"\s+"," ", s or "").strip()

def parse_date(text):
    if not text: return None
    d = dateparser.parse(text)
    return d.isoformat() if d else None

def discover_latest_links(max_n=15):
    # Grab links from homepage and movie news listing; keep first 15 unique article urls
    seeds = [BASE, urljoin(BASE, "/mnews")]
    seen, ordered = set(), []
    for seed in seeds:
        try:
            sp = soup(seed)
        except Exception as e:
            print(f"[warn] {seed}: {e}")
            continue

        # typical article links end with .html and live under /news/ or /mnews/ or /reviews/
        for a in sp.select("a[href]"):
            href = a.get("href","").strip()
            if href.startswith("/"):
                href = urljoin(BASE, href)
            if href.startswith(BASE) and href.endswith(".html") and (
                "/news/" in href or "/mnews/" in href or "/reviews/" in href
            ):
                if href not in seen:
                    seen.add(href)
                    ordered.append(href)
                if len(ordered) >= max_n:
                    return ordered
        time.sleep(0.3)  # be polite
    return ordered[:max_n]

def parse_article(url):
    sp = soup(url)

    title = (
        (sp.find("meta", property="og:title") or {}).get("content")
        or (sp.find("meta", attrs={"name":"twitter:title"}) or {}).get("content")
        or (sp.find("h1") or {}).get_text()
        or (sp.title.string if sp.title else None)
    )
    title = clean(title)

    published = (
        (sp.find("meta", property="article:published_time") or {}).get("content")
        or (sp.find("time") or {}).get("datetime")
        or (sp.find("time") or {}).get_text()
    )
    published = parse_date(clean(published) if published else None)

    author = (
        (sp.find("meta", attrs={"name":"author"}) or {}).get("content")
        or (sp.find("a", rel="author") or {}).get_text()
        or (sp.find(class_=re.compile("author", re.I)) or {}).get_text()
    )
    author = clean(author)

    # content blocks (fallback-friendly)
    candidates = [
        "article .entry-content p",
        ".td-post-content p",
        ".post-content p",
        ".entry-content p",
        "article p",
        "div[itemprop='articleBody'] p",
    ]
    nodes = []
    for sel in candidates:
        nodes = sp.select(sel)
        if len(nodes) >= 3:
            break
    if not nodes:
        nodes = sp.select("p")

    paras = []
    for p in nodes:
        txt = clean(p.get_text(" "))
        if len(txt) >= 30 and "copyright" not in txt.lower():
            paras.append(txt)
    content = "\n\n".join(paras).strip()

    return {
        "title": title,
        "url": url,
        "published": published,
        "author": author,
        "content_preview": (content[:400] + "…") if len(content) > 400 else content
    }

# ---- RUN ----
links = discover_latest_links(max_n=15)

articles = []
for i, link in enumerate(links, 1):
    try:
        art = parse_article(link)
        articles.append(art)
        # print to console nicely
        print(f"\n#{i}. {art['title']}")
        print(f"URL: {art['url']}")
        print(f"Published: {art['published'] or 'N/A'} | Author: {art['author'] or 'N/A'}")
        print("-" * 80)
        print(art["content_preview"] or "[No content found]")
        print("=" * 80)
    except Exception as e:
        print(f"[warn] failed: {link} -> {e}")
    time.sleep(0.8)  # polite delay
# Out:
# #1. Kantara Chapter 1’s Hindi version achieves a crucial milestone
# URL: https://www.123telugu.com/mnews/kantara-chapter-1s-hindi-version-achieves-a-crucial-milestone-prp.html
# Published: 2025-10-14T18:33:11+00:00 | Author: 123telugu
# --------------------------------------------------------------------------------
# Rishab Shetty’s Kantara: Chapter 1 is continuing its strong momentum at the box office. In its second weekend, the action drama witnessed a solid jump in revenues, proving the massive acceptance among the audience.
#
# While the Kannada version is storming the ticket windows, the Hindi version is also holding well. The latest update reveals that Kantara: Chapter 1 has entered the Rs. 150 crore nett c…
# ================================================================================
#
# #2. I want to make a love story with Mahesh Babu says sensational young director
# URL: https://www.123telugu.com/mnews/i-want-to-make-a-love-story-with-mahesh-babu-says-sensational-young-director-avd.html
# Published: 2025-10-14T19:30:23+00:00 | Author: 123telugu
# --------------------------------------------------------------------------------
# Director Sai Marthand, who scored a blockbuster with Little Hearts, has become the talk of the town in Telugu cinema. The film, starring Mouli and Shivani Nagaram, turned out to be one of the biggest hits of 2025, earning over ₹45 crore at the box office.
#
# In a recent interview, Sai Marthand revealed that he is an ardent fan of superstar Mahesh Babu and dreams of directing him one day.
#
# He added t…
# ================================================================================
#
# #3. Kiran Abbavaram smartly avoids OG talk during K-Ramp promotions
# URL: https://www.123telugu.com/mnews/kiran-abbavaram-smartly-avoids-og-talk-during-k-ramp-promotions-prp.html
# Published: 2025-10-14T17:34:17+00:00 | Author: 123telugu
# --------------------------------------------------------------------------------
# Kiran Abbavaram is very confident about his Diwali release K-Ramp. The movie, directed by Jains Nani, features Yukti Thareja as the female lead. Kiran, who is a huge fan of Powerstar Pawan Kalyan, made a thoughtful and sensible statement during K-Ramp promotions by choosing not to speak about OG.
#
# A fan asked Kiran Abbavaram to share his experience of watching OG on its first day, first show, to w…
# ================================================================================
#
# #4. Kantara music director for Ravi Teja’s next?
# URL: https://www.123telugu.com/mnews/kantara-music-director-for-ravi-tejas-next-prp.html
# Published: 2025-10-14T16:35:09+00:00 | Author: 123telugu
# --------------------------------------------------------------------------------
# Ravi Teja is gearing up to entertain audiences with Mass Jathara, which is set to release on October 31. After wrapping up a few promotional interviews, the actor flew to Spain for his upcoming film with Kishore Tirumala, which is scheduled for Sankranthi 2026 release.
#
# Apart from these films, Ravi Teja reportedly has another project with Shiva Nirvana of Majili fame. According to the latest buzz,…
# ================================================================================
#
# #5. Interview: Siddu Jonnalagadda – I believe my role in Telusu Kada will shock & surprise everyone
# URL: https://www.123telugu.com/mnews/interview-siddu-jonnalagadda-i-believe-my-role-in-telusu-kada-will-shock-surprise-everyone-prp.html
# Published: 2025-10-14T15:34:03+00:00 | Author: 123telugu
# --------------------------------------------------------------------------------
# Celebrity stylist Neerraja Kona is making her directorial debut with the romantic drama Telusu Kada, which features Siddu Jonnalagadda, Raashii Khanna, and Srinidhi Shetty. The triangular love story produced by TG Vishwa Prasad and Krithi Prasad under the People Media Factory banner is set for grand release on October 17. Ahead of the release, Siddu Jonnalagadda interacted with the media, and here…
# ================================================================================
#
# #6. Bigg Boss 9: Ramya Moksha wastes no time, sparks tension with Rithu Chowdary
# URL: https://www.123telugu.com/mnews/bigg-boss-9-ramya-moksha-wastes-no-time-sparks-tension-with-rithu-chowdary-avd.html
# Published: 2025-10-14T14:30:31+00:00 | Author: 123telugu
# --------------------------------------------------------------------------------
# Bigg Boss 9 Telugu just got spicier with the entry of Alekya Chitti Pickles fame Ramya Moksha. Ramya wasted no time in making her presence felt as she took contestant Demon Pawan aside and warned him to stay away from Rithu Chowdary.
#
# Her bold and calculated move has already created ripples inside the house and on social media. Viewers believe Ramya has entered the show with a clear strategy to gr…
# ================================================================================
#
# #7. Lokah OTT release: Jio Hotstar drops a teasing signal
# URL: https://www.123telugu.com/mnews/lokah-ott-release-jio-hotstar-drops-a-teasing-signal-prp.html
# Published: 2025-10-14T13:34:06+00:00 | Author: 123telugu
# --------------------------------------------------------------------------------
# The new industry of Mollywood, Lokah Chapter 1: Chandra, has recently surged past the Rs. 300 crore gross mark at the global box office. The movie starring Kalyani Priyadarshan in the lead role is also a solid hit in Telugu and Tamil.
#
# We have already stated that the film’s OTT rights were acquired by Jio Hotstar. The digital platform has officially confirmed the same now, and also dropped a teasi…
# ================================================================================
#
# #8. Vishnu Manchu’s Kannappa locks its world television premiere date
# URL: https://www.123telugu.com/mnews/vishnu-manchus-kannappa-locks-its-world-television-premiere-date-tv-prp.html
# Published: 2025-10-14T12:31:26+00:00 | Author: 123telugu
# --------------------------------------------------------------------------------
# Vishnu Manchu’s ambitious project Kannappa was lauded for its sincere attempt. The movie features the special cameos of PAN India star Prabhas, Akshay Kumar, Mohanlal, Mohan Babu, and Kajal Aggarwal. Mukesh Kumar Singh directed this flick.
#
# The latest update reveals that Kannappa will have its world television premiere on October 19 at 12 PM on Gemini TV as a Diwali treat. It remains to be seen ho…
# ================================================================================
#
# #9. OTT releases this week: Lokah, Kishkindhapuri, Final Destination Bloodlines & more on Jio Hotstar, ZEE5, and other platforms
# URL: https://www.123telugu.com/mnews/ott-releases-this-week-lokah-kishkindhapuri-final-destination-bloodlines-more-on-jio-hotstar-zee5-and-other-platforms-prp.html
# Published: 2025-10-14T11:28:25+00:00 | Author: 123telugu
# --------------------------------------------------------------------------------
# This Diwali season, some exciting content is set to arrive on OTT platforms. Here’s a curated list of notable releases that you can look forward to this festive weekend.
#
# How to Train Your Dragon is an American fantasy adventure film and a live-action remake of the 2010 animated film. Directed by Dean DeBlois, the film received positive reviews and has been commercially successful, grossing $635.7…
# ================================================================================
#
# #10. Meesaala Pilla from Chiranjeevi’s MSG: A pleasant melody about a separated couple
# URL: https://www.123telugu.com/mnews/meesaala-pilla-from-chiranjeevis-msg-a-pleasant-melody-about-a-separated-couple-prp.html
# Published: 2025-10-14T10:55:04+00:00 | Author: 123telugu
# --------------------------------------------------------------------------------
# Megastar Chiranjeevi’s next release is Mana Shankara Varaprasad Garu. Directed by Anil Ravipudi, the family entertainer will hit the big screens during Sankranthi 2026. Nayanthara plays the female lead. The promo of the first single, ‘Meesaala Pilla,’ created a rampage on social media.
#
# The full song was supposed to be released yesterday, but for some reason it has been released today. However, th…
# ================================================================================
#
# #11. Do not watch my films out of sympathy-K-Ramp star Kiran Abbavaram
# URL: https://www.123telugu.com/mnews/do-not-watch-my-films-out-of-sympathy-k-ramp-star-kiran-abbavaram-avd.html
# Published: 2025-10-14T09:26:22+00:00 | Author: 123telugu
# --------------------------------------------------------------------------------
# Kiran Abbavaram, who is gearing up for the release of his upcoming film K-Ramp, has made a strong statement ahead of its release on October 18, 2025.
#
# Speaking at a promotional interview, Kiran said, “I don’t want anyone to watch my films out of sympathy. I am not here to seek pity. If you genuinely like my promos and trailers, then come to the theatres.”
#
# The actor emphasized that he has a strong…
# ================================================================================
#
# #12. Telugu states’ breakeven targets for Telusu Kada, Dude, K-Ramp, & Mithra Mandali revealed
# URL: https://www.123telugu.com/mnews/telugu-states-breakeven-targets-for-telusu-kada-dude-k-ramp-mithra-mandali-revealed-prp.html
# Published: 2025-10-14T08:30:05+00:00 | Author: 123telugu
# --------------------------------------------------------------------------------
# This Diwali 2025 is going to be very exciting as four films are set to clash at the Tollywood box office. The movies in discussion are Siddu Jonnalagadda’s Telusu Kada, Pradeep Ranganathan’s Dude, Kiran Abbavaram’s K-Ramp, and Priyadarshi–Niharika NM’s Mithra Mandali.
#
# Telusu Kada has done the highest pre-release business among the four and needs to collect a distributor share of Rs. 17 crores to …
# ================================================================================
#
# #13. Duvvada Madhuri creates chaos in Bigg Boss 9 Telugu house
# URL: https://www.123telugu.com/mnews/duvvada-madhuri-creates-chaos-in-bigg-boss-9-telugu-house-avd.html
# Published: 2025-10-14T05:30:32+00:00 | Author: 123telugu
# --------------------------------------------------------------------------------
# Bigg Boss 9 Telugu has gotten even more dramatic with the entry of controversial personality Duvvada Madhuri. From the moment she stepped into the house, Madhuri has been at the center of chaos.
#
# On day 1 itself, she locked horns with Pawan Kalyan and Divya, leaving everyone stunned by her aggressive and rude behavior. Viewers are calling her entry a masterstroke by the makers, as her confrontatio…
# ================================================================================
#
# #14. OTT: Drishyam director’s latest crime thriller Mirage locks its streaming date
# URL: https://www.123telugu.com/mnews/ott-drishyam-directors-latest-crime-thriller-mirage-locks-its-streaming-date-prp.html
# Published: 2025-10-14T02:30:13+00:00 | Author: 123telugu
# --------------------------------------------------------------------------------
# Jeethu Joseph created quite a sensation with the Drishyam franchise. The acclaimed filmmaker has been planning to explore other genres moving away from crime thrillers, but interestingly, he is only being offered thriller scripts. His recent suspense thriller Mirage, featuring Asif Ali and Aparna Balamurali in the lead roles, opened to mixed reviews and ended up as a box-office failure.
#
# The film …
# ================================================================================
#
# #15. OTT: War 2 makes a stunning digital debut as India’s most-watched film last week
# URL: https://www.123telugu.com/mnews/ott-war-2-makes-a-stunning-digital-debut-as-indias-most-watched-film-last-week-prp.html
# Published: 2025-10-13T21:30:10+00:00 | Author: 123telugu
# --------------------------------------------------------------------------------
# Hrithik Roshan and NTR’s high-budget spy action thriller War 2 didn’t achieve the desired level of success in theatres. However, the biggie made a smashing debut on OTT following its underwhelming box office run. Netflix started streaming War 2 from October 9 in Hindi, Telugu, and Tamil languages.
#
# According to the latest report in Ormax, War 2 is the most-watched film last week (October 6 to Octo…
# ================================================================================
